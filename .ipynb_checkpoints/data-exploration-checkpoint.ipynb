# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
pay=pd.read_csv('paygap.csv')
speed=pd.read_csv('speeddating.csv')
oscar=pd.read_csv('oscars.csv', encoding = "ISO-8859-1")

# %%
oscar.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# 1                       1.0          White  ...  Best Director
# 2                       1.0          White  ...  Best Director
# 3                       1.0          White  ...  Best Director
# 4                       1.0          White  ...  Best Director
#
#                                       biourl  birthplace_gold  \
# 0  http://www.nndb.com/people/320/000043191/              NaN
# 1  http://www.nndb.com/people/626/000042500/              NaN
# 2  http://www.nndb.com/people/320/000043191/              NaN
# 3  http://www.nndb.com/people/544/000041421/              NaN
# 4  http://www.nndb.com/people/292/000044160/              NaN
#
#   date_of_birth_gold                           movie           person  \
# 0                NaN             Two Arabian Knights  Lewis Milestone
# 1                NaN                 The Divine Lady      Frank Lloyd
# 2                NaN  All Quiet on the Western Front  Lewis Milestone
# 3                NaN                          Skippy    Norman Taurog
# 4                NaN                        Bad Girl    Frank Borzage
#
#    race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 0                  NaN           NaN                     NaN
# 1                  NaN           NaN                     NaN
# 2                  NaN           NaN                     NaN
# 3                  NaN           NaN                     NaN
# 4                  NaN           NaN                     NaN
#
#   year_of_award_gold
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 27 columns]

# %%
pay.head()
# Out:
#               JobTitle  Gender  Age  PerfEval Education            Dept  \
# 0     Graphic Designer  Female   18         5   College      Operations
# 1    Software Engineer    Male   21         5   College      Management
# 2  Warehouse Associate  Female   19         4       PhD  Administration
# 3    Software Engineer    Male   20         5   Masters           Sales
# 4     Graphic Designer    Male   26         5   Masters     Engineering
#
#    Seniority  BasePay  Bonus
# 0          2    42363   9938
# 1          5   108476  11128
# 2          5    90208   9268
# 3          4   108080  10154
# 4          5    99464   9319

# %%
speed.head()
# Out:
#   has_null  wave     gender   age  age_o  d_age   d_d_age  \
# 0      b''   1.0  b'female'  21.0   27.0    6.0  b'[4-6]'
# 1      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 2      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 3      b''   1.0  b'female'  21.0   23.0    2.0  b'[2-3]'
# 4      b''   1.0  b'female'  21.0   24.0    3.0  b'[2-3]'
#
#                                        race  \
# 0  b'Asian/Pacific Islander/Asian-American'
# 1  b'Asian/Pacific Islander/Asian-American'
# 2  b'Asian/Pacific Islander/Asian-American'
# 3  b'Asian/Pacific Islander/Asian-American'
# 4  b'Asian/Pacific Islander/Asian-American'
#
#                                      race_o samerace  ...  \
# 0            b'European/Caucasian-American'     b'0'  ...
# 1            b'European/Caucasian-American'     b'0'  ...
# 2  b'Asian/Pacific Islander/Asian-American'     b'1'  ...
# 3            b'European/Caucasian-American'     b'0'  ...
# 4               b'Latino/Hispanic American'     b'0'  ...
#
#    d_expected_num_interested_in_me  d_expected_num_matches like  \
# 0                         b'[0-3]'                b'[3-5]'  7.0
# 1                         b'[0-3]'                b'[3-5]'  7.0
# 2                         b'[0-3]'                b'[3-5]'  7.0
# 3                         b'[0-3]'                b'[3-5]'  7.0
# 4                         b'[0-3]'                b'[3-5]'  6.0
#
#   guess_prob_liked    d_like  d_guess_prob_liked  met  decision  decision_o  \
# 0              6.0  b'[6-8]'            b'[5-6]'  0.0      b'1'        b'0'
# 1              5.0  b'[6-8]'            b'[5-6]'  1.0      b'1'        b'0'
# 2              NaN  b'[6-8]'            b'[0-4]'  1.0      b'1'        b'1'
# 3              6.0  b'[6-8]'            b'[5-6]'  0.0      b'1'        b'1'
# 4              6.0  b'[6-8]'            b'[5-6]'  0.0      b'1'        b'1'
#
#    match
# 0   b'0'
# 1   b'0'
# 2   b'1'
# 3   b'1'
# 4   b'1'
#
# [5 rows x 123 columns]

# %% [markdown]
# could look at religion, race, attractiveness. can also look at correlation between interests (shared interests). dataset includes answers to questionaires about the following:
# - (`_o`) what do i think my partner believes
# - (`_important`) what do i look for in a partner
# - (`_partner`) what do i rate my partner
# - no added tag --> what do i think of myself

# %%
# delete columns which just show the distribution buckets
clean_speed = speed[speed.columns.drop(list(speed.filter(regex='d_')))]

# %%
clean_speed.columns
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'race', 'race_o',
#        'samerace', 'importance_same_race', 'importance_same_religion', 'field',
#        'pref_o_attractive', 'pref_o_sincere', 'pref_o_intelligence',
#        'pref_o_funny', 'pref_o_ambitious', 'attractive_o', 'sinsere_o',
#        'intelligence_o', 'funny_o', 'ambitous_o', 'attractive_important',
#        'sincere_important', 'intellicence_important', 'funny_important',
#        'ambtition_important', 'attractive', 'sincere', 'intelligence', 'funny',
#        'ambition', 'attractive_partner', 'sincere_partner',
#        'intelligence_partner', 'funny_partner', 'ambition_partner', 'sports',
#        'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming',
#        'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music',
#        'shopping', 'yoga', 'interests_correlate', 'like', 'guess_prob_liked',
#        'met', 'decision', 'decision_o', 'match'],
#       dtype='object')

# %%
clean_speed
# Out:
#      has_null  wave     gender   age  age_o  \
# 0         b''   1.0  b'female'  21.0   27.0
# 1         b''   1.0  b'female'  21.0   22.0
# 2         b''   1.0  b'female'  21.0   22.0
# 3         b''   1.0  b'female'  21.0   23.0
# 4         b''   1.0  b'female'  21.0   24.0
# ...       ...   ...        ...   ...    ...
# 8373      b''  21.0    b'male'  25.0   26.0
# 8374      b''  21.0    b'male'  25.0   24.0
# 8375      b''  21.0    b'male'  25.0   29.0
# 8376      b''  21.0    b'male'  25.0   22.0
# 8377      b''  21.0    b'male'  25.0   22.0
#
#                                           race  \
# 0     b'Asian/Pacific Islander/Asian-American'
# 1     b'Asian/Pacific Islander/Asian-American'
# 2     b'Asian/Pacific Islander/Asian-American'
# 3     b'Asian/Pacific Islander/Asian-American'
# 4     b'Asian/Pacific Islander/Asian-American'
# ...                                        ...
# 8373            b'European/Caucasian-American'
# 8374            b'European/Caucasian-American'
# 8375            b'European/Caucasian-American'
# 8376            b'European/Caucasian-American'
# 8377            b'European/Caucasian-American'
#
#                                         race_o samerace  importance_same_race  \
# 0               b'European/Caucasian-American'     b'0'                   2.0
# 1               b'European/Caucasian-American'     b'0'                   2.0
# 2     b'Asian/Pacific Islander/Asian-American'     b'1'                   2.0
# 3               b'European/Caucasian-American'     b'0'                   2.0
# 4                  b'Latino/Hispanic American'     b'0'                   2.0
# ...                                        ...      ...                   ...
# 8373               b'Latino/Hispanic American'     b'0'                   1.0
# 8374                                  b'Other'     b'0'                   1.0
# 8375               b'Latino/Hispanic American'     b'0'                   1.0
# 8376  b'Asian/Pacific Islander/Asian-American'     b'0'                   1.0
# 8377  b'Asian/Pacific Islander/Asian-American'     b'0'                   1.0
#
#       importance_same_religion  ... music  shopping  yoga  \
# 0                          4.0  ...   9.0       8.0   1.0
# 1                          4.0  ...   9.0       8.0   1.0
# 2                          4.0  ...   9.0       8.0   1.0
# 3                          4.0  ...   9.0       8.0   1.0
# 4                          4.0  ...   9.0       8.0   1.0
# ...                        ...  ...   ...       ...   ...
# 8373                       1.0  ...  10.0       7.0   3.0
# 8374                       1.0  ...  10.0       7.0   3.0
# 8375                       1.0  ...  10.0       7.0   3.0
# 8376                       1.0  ...  10.0       7.0   3.0
# 8377                       1.0  ...  10.0       7.0   3.0
#
#       interests_correlate  like  guess_prob_liked  met  decision  decision_o  \
# 0                    0.14   7.0               6.0  0.0      b'1'        b'0'
# 1                    0.54   7.0               5.0  1.0      b'1'        b'0'
# 2                    0.16   7.0               NaN  1.0      b'1'        b'1'
# 3                    0.61   7.0               6.0  0.0      b'1'        b'1'
# 4                    0.21   6.0               6.0  0.0      b'1'        b'1'
# ...                   ...   ...               ...  ...       ...         ...
# 8373                 0.64   2.0               5.0  0.0      b'0'        b'1'
# 8374                 0.71   4.0               4.0  0.0      b'0'        b'0'
# 8375                -0.46   6.0               5.0  0.0      b'0'        b'0'
# 8376                 0.62   5.0               5.0  0.0      b'0'        b'1'
# 8377                 0.01   4.0               5.0  0.0      b'0'        b'1'
#
#       match
# 0      b'0'
# 1      b'0'
# 2      b'1'
# 3      b'1'
# 4      b'1'
# ...     ...
# 8373   b'0'
# 8374   b'0'
# 8375   b'0'
# 8376   b'0'
# 8377   b'0'
#
# [8378 rows x 60 columns]
